# %% [markdown]
# # Para problemas de clasificación

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

y_true = [1,0,0,0,1,1,0]
y_pred = [0,1,1,0,0,1,0]

accuracy = accuracy_score(y_true,y_pred)
accuracy

precision = precision_score(y_true,y_pred)
precision

sensib=recall_score(y_true,y_pred)

f1 = f1_score(y_true,y_pred)

f1
# Out:
# 0.3333333333333333

# %%
from sklearn.metrics import confusion_matrix

cm= confusion_matrix(y_true,y_pred)
cm

tn, fp, fn, tp = confusion_matrix(y_true,y_pred).ravel() #aplana arrays.

import matplotlib.pyplot as plt
import seaborn as sns
clases= ["0 No spam", "1 Spam"]
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot = True, cmap= "Greens", fmt = "g", xticklabels=clases, yticklabels = clases)

plt.show()
plt.close()

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, ths = roc_curve(y_true,y_pred)
print(f"Tasa de falsos positivos: {fpr}")
print(f"Tasa de verdaderos positivos: {tpr}")
print(f"umbrales de binarización: {ths}")
#estos puntos de corte se dan porque le damos etiquetas a la función (0,1) y no probabilidades.
# Out:
# Tasa de falsos positivos: [0.  0.5 1. ]
# Tasa de verdaderos positivos: [0.         0.33333333 1.        ]
# umbrales de binarización: [inf  1.  0.]

# %%
# %pip install ucimlrepo
from ucimlrepo import fetch_ucirepo
# Out:
# Collecting ucimlrepo
#   Using cached ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\sebitas\appdata\local\programs\python\python313\lib\site-packages (from ucimlrepo) (3.0.1)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\sebitas\appdata\local\programs\python\python313\lib\site-packages (from ucimlrepo) (2024.8.30)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sebitas\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sebitas\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sebitas\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\sebitas\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Using cached ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: C:\Users\Sebitas\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
df = fetch_ucirepo(id=45)

# %%
X = df.data.features
y=df.data.targets

# %%
import numpy as np

y_bin = y.copy()
y_bin[:] = np.where(y>=1,1,0)
print(y.head())
print(y_bin.head())
# Out:
#    num
# 0    0
# 1    2
# 2    1
# 3    0
# 4    0
#    num
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0

# %%
variables = X.columns
X.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# dtype: int64
