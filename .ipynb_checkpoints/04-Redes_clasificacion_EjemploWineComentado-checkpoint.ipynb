# %% [markdown]
# ## Redes clasificación Wine-red
# _Ejemplo_ Wine quality-red
# Tratar de predecir si un vino es de calidad alta (7), o no (resto de calidades) utilizando redes neuronales
# Aplicar selectKbest como selector de 4 variables input candidatas

# %%
#importar las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
import seaborn as sns
import plotly.graph_objects as go
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer, Binarizer, RobustScaler, label_binarize
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, PowerTransformer
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.tree import DecisionTreeClassifier, export_text, DecisionTreeRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc
from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ### INCISO
# `PowerTransformer` es una clase de `sklearn.preprocessing` que aplica transformaciones de potencia a las variables numéricas para hacer que su distribución sea más parecida a una distribución normal (gaussiana). Esto suele mejorar el rendimiento de modelos que asumen normalidad, y también reduce asimetrías y heterocedasticidad.

# %%
seed=12345 #fijamos la semilla de aleatorización para que sea la misma en todo el proceso
#Reemplaza con la ruta correcta y nombre de tu archivo
file_path = 'C:/Users/user/OneDrive - Universidad Complutense de Madrid (UCM)/Documentos/Titulo Propio/Machine Learning/Redes Neuronales/Python/Datasets/winequality-red.csv' 
#convertir a data frame el archivo
df = pd.read_csv(file_path,sep=";")
print(f'\n Instancias: {df.shape[0]}; Variables: {df.columns}')
#La variable de interés es chd, binaria Si/No
#analizamos la frecuencia de cada clase
print(f'\n Instancias: {df.shape[0]}; Variables: {df.shape[1]}')
print(f'\nLa frecuencia de cada clase es: \n{df.quality.value_counts()}')
# Out:
#  Instancias: 1599; Variables: Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
#
#  Instancias: 1599; Variables: 12
#
# La frecuencia de cada clase es:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
# Definimos una variable respuesta highQuality a partir de quality
df['highQuality'] = df['quality'].apply(lambda x: 1 if x > 6 else 0)

# %%
print(f'\nLa frecuencia de cada clase es de highQuality: \n{df.highQuality.value_counts()}')
# Out:
# La frecuencia de cada clase es de highQuality:
# highQuality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %%
print(df.head())
df.shape # Mostrar la forma del DataFrame (número de filas y columnas)
print(f'tipo de las variables {df.dtypes}') # Mostrar los tipos de datos de las columnas
df.describe() # Mostrar estadísticas descriptivas del DataFrame
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#   alcohol  quality  highQuality
# 0     9.4        5            0
# 1     9.8        5            0
# 2     9.8        5            0
# 3     9.8        6            0
# 4     9.4        5            0
# tipo de las variables fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                  object
# quality                   int64
# highQuality               int64
# dtype: object
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     2.208702
# std       0.047065            10.460157             32.895324     9.664060
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000   100.369000
#
#                 pH    sulphates      quality  highQuality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149     5.636023     0.135710
# std       0.154386     0.169507     0.807569     0.342587
# min       2.740000     0.330000     3.000000     0.000000
# 25%       3.210000     0.550000     5.000000     0.000000
# 50%       3.310000     0.620000     6.000000     0.000000
# 75%       3.400000     0.730000     6.000000     0.000000
# max       4.010000     2.000000     8.000000     1.000000

# %%
#convertimos la variable alcohol a numérica
df['alcohol'] = pd.to_numeric(df['alcohol'], errors='coerce')
print(f'tipo de las variables {df.dtypes}') # Mostrar los tipos de datos de las columnas
# Out:
# tipo de las variables fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# highQuality               int64
# dtype: object

# %% [markdown]
# ## Correlación
# Si hay correlación, ¿con qué variable me quedo? No existe una regla única, pero algunas ideas prácticas pueden ser:
#
# a) Interpretabilidad: Qué variable es más fácil de explicar al usuario/negocio.
#
# b) Importancia para el modelo: Revisar feature importance, coeficientes, o SHAP.
#
# c) Calidad de datos: Variables con menos missing, menos ruido, mayor estabilidad.
#
# d) Criterio estadístico: Aquella que tenga mayor correlación con la variable objetivo
#
# Si citric_acid, volatile_acidity y pH están correlacionadas entre sí, pero pH es clínicamente más interpretable (en vinos lo es), podrías quedarte con pH, salvo que la métrica del modelo mejore con otra.
#
#
# **Correlaciones (en valor absoluto):**
# - | 0.0 - 0.2 | muy débil
# - | 0.2 - 0.4 | débil
# - | 0.4 - 0.6 | moderada
# - | 0.6 - 0.8 | fuerte
# - | 0.8 - 1.0 | muy fuerte
#
#
# En ML muchas veces se suelen considerar potencialmente problemáticas correlaciones |r| > 0.8 porque implican multicolinealida

# %%
corr=df.corr() # Calcular la matriz de correlación entre las características numérica
#hay algunas correlaciones importantes, como por ejemplo citric acid-volatile acidity-ph. Podríamos considerar quedarnos sólo con una

import seaborn as sns
import matplotlib.pyplot as plt

# Mapa de calor
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.show()

# %% [markdown]
# ## Filtrar variables con mucha correlación: no hay

# %%
umbral = 0.8
corr_pairs = np.where(abs(corr) > umbral)

for i, j in zip(corr_pairs[0], corr_pairs[1]):
    if i < j:  # para evitar duplicados y la diagonal
        print(f"{corr.index[i]} - {corr.columns[j]}: {corr.iloc[i, j]:.2f}")

# %%
# hay valores perdidos?
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 6
# quality                 0
# highQuality             0
# dtype: int64

# %% [markdown]
# Preparamos la base de datos para la aplicación de redes neuronales:
#
#     - Estandarizar/normalizar variables continuas
#     - Convertir a dummies las variables categóricas
#     - Evitar missing

# %%
#borramos los datos missing de alcohol
df = df.dropna()
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# highQuality             0
# dtype: int64

# %%
# organiza las variables según su rol y naturaleza
# determina variable objetivo
target = "highQuality"
#hacer una lista con las variables input numericas
num_cols = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
#hacer una lista con las variables input categóricas
cat_cols = []

# %% [markdown]
# `GridSearchCV` es una función de la biblioteca scikit-learn que se utiliza para realizar una búsqueda exhaustiva sobre un conjunto especificado de hiperparámetros para un modelo de aprendizaje automático. La idea es probar todas las combinaciones posibles de hiperparámetros especificados en una cuadrícula y seleccionar la combinación que ofrece el mejor rendimiento según una métrica determinada.
#
# 1. **Definición del Modelo:** Se selecciona un modelo junto con un conjunto de hiperparámetros para optimizar. Los hiperparámetros son configuraciones ajustables que afectan el rendimiento y el comportamiento del modelo.
#
# 2. **Definición de la Cuadrícula/Rejilla de Parámetros:** Se especifican los valores posibles para cada hiperparámetro que se desea ajustar. `GridSearchCV` probará todas las combinaciones posibles de estos valores.
#
# 3. **División de Datos:** Los datos se dividen en conjuntos de entrenamiento y prueba. Durante la búsqueda de la cuadrícula, el modelo se ajusta a los datos de entrenamiento y se evalúa en el conjunto de prueba.
#
# 4. **Evaluación del Rendimiento:** Se elige una métrica de evaluación, como precisión, exactitud, F1-score, etc. (¡depende del problema considerado!). Esta métrica se utilizará para evaluar el rendimiento del modelo en cada combinación de hiperparámetros.
#
# 5. **Búsqueda Exhaustiva:** `GridSearchCV` realiza una búsqueda exhaustiva probando todas las combinaciones posibles de hiperparámetros en la cuadrícula. Ajusta el modelo con cada combinación y evalúa su rendimiento utilizando la métrica especificada.
#
# 6. **Selección del Mejor Modelo:** Una vez que se han probado todas las combinaciones, `GridSearchCV` selecciona la combinación de hiperparámetros que proporcionó el mejor rendimiento según la métrica elegida.
#
# `GridSearchCV` automatiza el proceso de ajuste de hiperparámetros al probar sistemáticamente diferentes combinaciones, lo que facilita la identificación de la configuración óptima para un modelo en particular.
#
# `refit` es un parámetro que determina si ajustar o no el estimador final utilizando los mejores hiperparámetros encontrados durante la búsqueda en la cuadrícula.
#
# Cuando refit está establecido en True (que es el valor predeterminado), después de completar la búsqueda en la cuadrícula, GridSearchCV ajustará automáticamente el estimador utilizando los mejores hiperparámetros encontrados en todo el conjunto de datos de entrenamiento.
#
# **IMPORTANTE** el valor añadido de un analista es encontrar el equilibrio entre la calidad del modelo y su complejidad, las necesidades y requerimientos de cada problema, el mantenimiento y cuidado que se le podrá prestar al modelo, etc. Limitarse al "mejor modelo" propocionado por GridSearchCV sería nuestro final como analistas. Es IMPRESCINDIBLE ir más allá de la parametrización que optimiza numéricamente la medida de bondad escogida.

# %% [markdown]
# ## Selección de variables
# 1. Paso preliminar para escoger unas buenas variables input candidatas. Lo hacemos con selectkbest, usando k=4.
# - Algunas funciones de evaluación como _f_classif_ y _f_regression_, no necesitan que los datos estén normalizados, ya que son pruebas estadísticas que evalúan la relación entre cada característica y la variable objetivo sin considerar la escala de las características.
# - Otras  como chi2, son sensibles a las magnitudes de las características y pueden producir resultados sesgados si las características no están en la misma escala. En estos casos, es recomendable normalizar o estandarizar.
# - Como en este caso se aplica _seleckbest_ de forma puramente descriptiva como selector de variables, omitimos la normalización
#
# A continuación se muestra un ejemplo "mala praxis" de cómo se seleccionarían. Lo suyo es integrar esta parte en el flujo completo de trabajo, **después** de la estandarización, ya que muchos criterios que usan SelectKBest o RFE dependen de la magnitud de las variables.
#
# Si usamos para seleccionar variables otros métodos como un árbol que selecciona variables en función de su importancia, la magnitud de las variables no importa y por tanto da igual dónde hacer la selección.
#
#
# **PARA EVITAR PROBLEMAS**: acostumbrémonos a hacerlo despues de la transformación de variables

# %%
### Ejemplo de cómo seleccionar variables
from sklearn.feature_selection import SelectKBest, f_classif
selector = SelectKBest(score_func=f_classif, k=4)
# Inicializar el selector para elegir las 4 mejores características
selector.fit(df[num_cols], df[target])
# Obtener los nombres de las características seleccionadas
selected_features = df[num_cols].columns[selector.get_support()]
print("Características seleccionadas:", selected_features)
# Out:
# Características seleccionadas: Index(['volatile acidity', 'citric acid', 'sulphates', 'alcohol'], dtype='object')

# %% [markdown]
# ## OJO
# `SelectKBest` depende de la magnitud de las variables, por lo que habría que aplicarlo después de la estandarización. Se muestra a continuación el flujo completo.
#
# Cuidado, no normalizar, pues necesito valores no negativos.

# %%
# Tuneo y evaluación predictiva del modelo para variable dependiente continua
# El grupo de variables predictoras se define y se fija. A partir de este grupo haré la selección
X = df[num_cols] #en X las variables  están sin normalizar. Tomo todas
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest,f_classif

# Inicializar el escalador
scaler = MinMaxScaler()
# Ajustar el escalador solo con los datos de entrenamiento y transformar
X_train = scaler.fit_transform(X_train)
# Transformar el conjunto de prueba utilizando el mismo escalador
X_test = scaler.transform(X_test) #Ojo que estos elementos no son un df con variables

# Inicializar el selector
selector = SelectKBest(f_classif, k=4)
# Ajustar el selector solo con los datos de entrenamiento y transformar (aplicar la selección para que al entenar el modelo sólo use esas variables)
X_train = selector.fit_transform(X_train, y_train)
# Transformar el conjunto de prueba utilizando el mismo selector: escoger las variables marcadas en train
X_test = selector.transform(X_test) #Ojo que estos elementos no son un df con variables

# %% [markdown]
# Llegados a este punto...
# - X_train tiene las variables con cambio de escala con su max y su min, y sólo incluye las 4 variables seleccionadas
# - X_test tiene las variables con cambio de escala con el max y min encontrados en X_train, y sólo incluye las 4 variables propuestas en train

# %%
red = MLPClassifier(random_state=seed)
#definimos los parámetros que queremos tunear
#suponiendo que reservamos unas 20 observaciones por parámetro, deberíamos probar con no más de 15 nodos en la capa oculta
#por el principio de parsimonia, ante igualdad de resultados, mejor modelos sencillos
params = {
    'max_iter': [600], #cantidad de iteraciones que se le permiten al algoritmo de optimizacion
    'hidden_layer_sizes': [7,9,11,13,15],#redes con una sola capa oculta, con un tamaño distinto en cada arquitectura
    'activation': ['tanh','relu'], #función de activación usada
    'alpha': [0.001,0.0001] #regularización L2, valor alto puede resultar en un modelo más sesgado pero con menor varianza. 
    #valor más bajo permite que el modelo se ajuste más a los datos de tr, aunque con un mayor riesgo de sobreajuste
}
scoring_metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']
# cv = crossvalidation con n folds con todas las combinaciones de parámetros
# GridSearchCV utiliza la función .predict como método subyacente, por lo tanto, clasifica
#en la clase con probabilidad más alta, lo que es equivalente a usar 0.5 como threshold
grid_search = GridSearchCV(estimator=red, 
                           param_grid=params, 
                           cv=4, scoring = scoring_metrics, refit='accuracy')

#ajusta en entrenamiento con todas las combinaciones
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (600) reached and the optimization hasn't converged yet.
#   warnings.warn(
# GridSearchCV(cv=4, estimator=MLPClassifier(random_state=12345),
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.001, 0.0001],
#                          'hidden_layer_sizes': [7, 9, 11, 13, 15],
#                          'max_iter': [600]},
#              refit='accuracy',
#              scoring=['accuracy', 'precision_macro', 'recall_macro',
#                       'f1_macro'])

# %% [markdown]
# ## Sobre la convergencia
# Algunos modelos no han alcanzado la convergencia...
#
# En NN _converger_ significa que el entrenamiento ha estabilizado la función de pérdida y no mejora más. Si no converge, significa que el optimizador no ha llegado a esa estabilidad antes del límite de iteraciones. No siempre es un problema: puede ser solo un aviso si el modelo funciona bien; pero es un problema si la pérdida sigue alta o el modelo no aprende.

# %%
# Obtener resultados del grid search
results = pd.DataFrame(grid_search.cv_results_)
# Mostrar resultados
print("Resultados de Grid Search:")
print(results[['params', 'mean_test_accuracy', 'mean_test_precision_macro', 'mean_test_recall_macro', 'mean_test_f1_macro']])
#print(results) #para ver todos los atributos obtenidos y entender cómo usarlos

# Obtener el mejor modelo (en cuanto a optimización del criterio)
best_model = grid_search.best_estimator_
print(grid_search.best_estimator_)
# Out:
# Resultados de Grid Search:
#                                                params  mean_test_accuracy  \
# 0   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.879922
# 1   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.883056
# 2   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.877566
# 3   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.877563
# 4   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.878352
# 5   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.879922
# 6   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.883056
# 7   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.877566
# 8   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.877563
# 9   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.878352
# 10  {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.872067
# 11  {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.878352
# 12  {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.875996
# 13  {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.876782
# 14  {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.875207
# 15  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.871284
# 16  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.880705
# 17  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.875996
# 18  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.876782
# 19  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.875207
#
#     mean_test_precision_macro  mean_test_recall_macro  mean_test_f1_macro
# 0                    0.753161                0.612570            0.641475
# 1                    0.767285                0.626791            0.658311
# 2                    0.737420                0.616258            0.643192
# 3                    0.737482                0.618712            0.645715
# 4                    0.741071                0.614188            0.641888
# 5                    0.753161                0.612570            0.641475
# 6                    0.767285                0.626791            0.658311
# 7                    0.737420                0.616258            0.643192
# 8                    0.737482                0.618712            0.645715
# 9                    0.741071                0.614188            0.641888
# 10                   0.757319                0.552806            0.559785
# 11                   0.740159                0.614257            0.640644
# 12                   0.730566                0.612829            0.638843
# 13                   0.733245                0.608304            0.634633
# 14                   0.729366                0.612307            0.638898
# 15                   0.753828                0.549899            0.556004
# 16                   0.756392                0.620524            0.650050
# 17                   0.730566                0.612829            0.638843
# 18                   0.733245                0.608304            0.634633
# 19                   0.729366                0.612307            0.638898
# MLPClassifier(activation='tanh', alpha=0.001, hidden_layer_sizes=9,
#               max_iter=600, random_state=12345)

# %% [markdown]
# Si escogemos una mejor parametrización con aproximadamente 13 nodos, deberíamos probar con valores cercanos no evaluados, como 12 y 14.
# De la misma forma, si nuestra mejor arquitectura fuera una en el extremo de la parrilla (la más sencilla o la más compleja), deberíamos seguir buscando, reduciendo al complejidad (respectivamente aumentándola), pues nada nos garantiza que en la parrilla hayamos incluido las mejores opciones

# %%
red = MLPClassifier(random_state=seed)
#definimos los parámetros que queremos tunear
#suponiendo que reservamos unas 20 observaciones por parámetro, deberíamos probar con no más de 15 nodos en la capa oculta
#por el principio de parsimonia, ante igualdad de resultados, mejor modelos sencillos
params = {
    'max_iter': [600], #cantidad de iteraciones que se le permiten al algoritmo de optimizacion
    'hidden_layer_sizes': [12,13,14],#redes con una sola capa oculta, con un tamaño distinto en cada arquitectura
    'activation': ['tanh','relu'], #función de activación usada
    'alpha': [0.001,0.0001] #regularización L2, valor alto puede resultar en un modelo más sesgado pero con menor varianza. 
    #valor más bajo permite que el modelo se ajuste más a los datos de tr, aunque con un mayor riesgo de sobreajuste
}
scoring_metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']
# cv = crossvalidation con n folds con todas las combinaciones de parámetros
# GridSearchCV utiliza la función .predict como método subyacente, por lo tanto, clasifica
#en la clase con probabilidad más alta, lo que es equivalente a usar 0.5 como threshold
grid_search = GridSearchCV(estimator=red, 
                           param_grid=params, 
                           cv=4, scoring = scoring_metrics, refit='accuracy')

#ajusta en entrenamiento con todas las combinaciones
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=MLPClassifier(random_state=12345),
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.001, 0.0001],
#                          'hidden_layer_sizes': [12, 13, 14],
#                          'max_iter': [600]},
#              refit='accuracy',
#              scoring=['accuracy', 'precision_macro', 'recall_macro',
#                       'f1_macro'])

# %%
# Obtener resultados del grid search
results = pd.DataFrame(grid_search.cv_results_)
# Mostrar resultados
print("Resultados de Grid Search:")
print(results[['params', 'mean_test_accuracy', 'mean_test_precision_macro', 'mean_test_recall_macro', 'mean_test_f1_macro']])
#print(results) #para ver todos los atributos obtenidos y entender cómo usarlos

# Obtener el mejor modelo (en cuanto a optimización del criterio)
best_model = grid_search.best_estimator_
print(grid_search.best_estimator_)
# Out:
# Resultados de Grid Search:
#                                                params  mean_test_accuracy  \
# 0   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.880708
# 1   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.877563
# 2   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.877566
# 3   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.880708
# 4   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.877563
# 5   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.877566
# 6   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.880708
# 7   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.876782
# 8   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.877563
# 9   {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.880708
# 10  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.876782
# 11  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.877563
#
#     mean_test_precision_macro  mean_test_recall_macro  mean_test_f1_macro
# 0                    0.755951                0.620524            0.649957
# 1                    0.737482                0.618712            0.645715
# 2                    0.738397                0.618712            0.646036
# 3                    0.755951                0.620524            0.649957
# 4                    0.737482                0.618712            0.645715
# 5                    0.738397                0.618712            0.646036
# 6                    0.771680                0.605453            0.635285
# 7                    0.733245                0.608304            0.634633
# 8                    0.738777                0.613735            0.641042
# 9                    0.771680                0.605453            0.635285
# 10                   0.733245                0.608304            0.634633
# 11                   0.738777                0.613735            0.641042
# MLPClassifier(activation='tanh', alpha=0.001, hidden_layer_sizes=12,
#               max_iter=600, random_state=12345)

# %% [markdown]
# ## Cuidado con los dtos desbalanceados!!!!!!
# Como los datos son muy desbalanceados, es importante fijarse en la sensibilidad-recall. Por lo tanto, seleccionamos como candidatas las redes con arquitecturas  1, 2 y 10

# %%
# se seleccionan los modelos candidatos, y analiza su robustez a lo largo de cross validation.
ac_1 = results[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[1]
ac_2 = results[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[2]
ac_3 = results[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[10]

# %%
# Crear un boxplot para los cuatro valores de accuracy
plt.boxplot([ac_1.values,ac_2.values,ac_3.values], tick_labels = ['Red1','Red2','Red10'])
plt.title('Boxplots de Accuracy para los 4 Splits')
plt.xlabel('Splits de Cross Validation')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Parece que la red 1 es la más estable de las 3, y en mediana son similares, veamos los hiperparámetros

# %%
print(f'Arquitectura red 1: {results.iloc[1].params}')
print(f'Arquitectura red 2: {results.iloc[2].params}')
print(f'Arquitectura red 10: {results.iloc[10].params}')
# Out:
# Arquitectura red 1: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 13, 'max_iter': 600}
# Arquitectura red 2: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 14, 'max_iter': 600}
# Arquitectura red 10: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 13, 'max_iter': 600}

# %% [markdown]
# Por complejidad, compensa la red 1 a la 2. Por calidad, la red 1 a la 10.
# Como 13 ya no está en un extremo, podríamos optar por esta red como modelo candidato.
# Antes de ponerlo en producción, tenemos que entrenarlo, haciendo que los datos pasen por exactamente el mismo proceso de transformación y slección de variables

# %%
# El grupo de variables predictoras se define y se fija. A partir de este grupo haré la selección
X = df[num_cols] #en X las variables  están sin normalizar. Tomo todas
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest,f_classif

# Inicializar el escalador
scaler = MinMaxScaler()
# Ajustar el escalador solo con los datos de entrenamiento y transformar
X_train = scaler.fit_transform(X_train)
# Transformar el conjunto de prueba utilizando el mismo escalador
X_test = scaler.transform(X_test) #Ojo que estos elementos no son un df con variables

# Inicializar el selector
selector = SelectKBest(f_classif, k=4)
# Ajustar el selector solo con los datos de entrenamiento y transformar (aplicar la selección para que al entenar el modelo sólo use esas variables)
X_train = selector.fit_transform(X_train, y_train)
# Transformar el conjunto de prueba utilizando el mismo selector: escoger las variables marcadas en train
X_test = selector.transform(X_test) #Ojo que estos elementos no son un df con variables

candidata = MLPClassifier(**results.iloc[1].params,random_state=seed)
candidata.fit(X_train, y_train)


# Calculamos las predicciones en test, en términos de probabilidad para poder dibujar el AUC
y_pred = candidata.predict_proba(X_test)[:,1]

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f"\nÁrea bajo la curva ROC (AUC) para la red 0 en test: {roc_auc:.2f}")

# Graficar la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC candidata')
plt.legend(loc="lower right")
plt.show()

#calculamos las predicciones en test, en términos de probabilidad para poder dibujar el AUC
y_pred = candidata.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
print("Matriz de Confusión:")
print(conf_matrix)
print("\nMedidas de Desempeño:")
print(classification_report(y_test, y_pred))

#También podríamos haber binarizado y_pred proba con el umbral que mejor nos venga
# Out:
# Área bajo la curva ROC (AUC) para la red 0 en test: 0.83
# Matriz de Confusión:
# [[259  14]
#  [ 39   7]]
#
# Medidas de Desempeño:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       273
#            1       0.33      0.15      0.21        46
#
#     accuracy                           0.83       319
#    macro avg       0.60      0.55      0.56       319
# weighted avg       0.79      0.83      0.81       319

# %% [markdown]
# ## Interpretación:
# No es un buen modelo, apenas acierta la clase de interes, los verdaderos positivos. El accuracy nos "engaña" porque en general casi siempre dice 0, y como los datos están muy desbalanceados, acierta bastante. Pero lo interesante es detectar la categoría 1.
#
#
# ¿Qué ha pasado? ¿Puedo relacionar esta situación con los datos? ¿Hay sobreajuste? ¿La red parecía un modelo sensato para este problema?...
