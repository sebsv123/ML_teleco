# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_text, DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc
from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
iris = load_iris(as_frame = True)
df = iris.frame.copy()

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
sepal = df["sepal length (cm)"]
print(sepal)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
petal_w = df["petal width (cm)"]

def random_upper_series(df, s, p=0.7, random_state=None, inplace=False):
    rng = np.random.default_rng(random_state)

    if not inplace:
        df = df.copy()
        
    s = df["sepal length (cm)"]
    colname = s.name            
    q3 = s.quantile(0.75)

    upper_mask = s >= q3
    to_nan = upper_mask & (rng.random(len(df)) < p)

    df.loc[to_nan, colname] = np.nan
    return df

# %%
df["sepal length (cm)"].value_counts()
# Out:
# sepal length (cm)
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 6.4     7
# 5.5     7
# 5.8     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 6.2     4
# 4.4     3
# 7.2     3
# 5.9     3
# 6.8     3
# 4.7     2
# 6.6     2
# 4.3     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.1     1
# 7.3     1
# 7.6     1
# 7.4     1
# 7.9     1
# Name: count, dtype: int64

# %%
df["petal width (cm)"].value_counts()
# Out:
# petal width (cm)
# 0.2    29
# 1.3    13
# 1.5    12
# 1.8    12
# 1.4     8
# 2.3     8
# 0.4     7
# 1.0     7
# 0.3     7
# 2.1     6
# 2.0     6
# 1.2     5
# 0.1     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 1.1     3
# 2.4     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: count, dtype: int64

# %%
df2["petal width (cm)"].value_counts()
# Out:
# petal width (cm)
# 0.2    29
# 1.3    13
# 1.5    12
# 1.4     8
# 0.3     7
# 0.4     7
# 1.0     7
# 1.2     5
# 0.1     5
# 1.6     4
# 1.1     3
# 1.8     3
# 1.7     2
# 2.5     2
# 2.2     2
# 0.5     1
# 0.6     1
# 2.1     1
# 2.3     1
# 2.0     1
# 2.4     1
# 1.9     1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df2 = random_upper(df, petal_w.name, p=0.7, random_state=42)
df2.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df2["tiene_NA"] = df2.isna().any(axis=1).astype(int)
print(df2["tiene_NA"])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: tiene_NA, Length: 150, dtype: int64

# %%
df2.isna().sum()
# Out:
# sepal length (cm)     0
# sepal width (cm)      0
# petal length (cm)     0
# petal width (cm)     34
# target                0
# tiene_NA              0
# dtype: int64

# %%
df2.value_counts()
# Out:
# sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target  tiene_NA
# 4.3                3.0               1.1                0.1               0       0           1
# 4.4                2.9               1.4                0.2               0       0           1
#                    3.0               1.3                0.2               0       0           1
#                    3.2               1.3                0.2               0       0           1
# 4.5                2.3               1.3                0.3               0       0           1
#                                                                                              ..
# 7.2                3.0               5.8                1.6               2       0           1
#                    3.6               6.1                2.5               2       0           1
# 7.6                3.0               6.6                2.1               2       0           1
# 7.7                3.8               6.7                2.2               2       0           1
# 7.9                3.8               6.4                2.0               2       0           1
# Name: count, Length: 116, dtype: int64

# %%
df2["tiene_NA"].value_counts()
# Out:
# tiene_NA
# 0    116
# 1     34
# Name: count, dtype: int64

# %%
## Creación del árbol para saber de qué depende la presencia de NAs:

# %%
#es importante tratar de forma adecuada las variables categóricas. Se convierten en numéricas con la regla: one hot encoding.
# Separar las variables predictoras y la variable de respuesta.
#X = df2.drop("tiene_NA", axis=1)
X = df2[["sepal length (cm)", "sepal width (cm)", "petal length (cm)"]]
y = df2["tiene_NA"]
#Se selecciona profundidad 4 sólo con caracter ilustrativo, al simplificar el árbol.
arbol2 = DecisionTreeClassifier(min_samples_split=30, criterion="gini", max_depth = 4)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Construir el modelo de árbol de decisiones
arbol2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_split=30)

# %%
plt.figure(figsize=(15, 15))
plot_tree(arbol2, feature_names=X.columns.tolist(),
class_names=["No", "Yes"], filled=True,
proportion = True)
plt.show()

# %%
## tuneo y evaluación predictiva del modelo para variable dependiente categórica.
params = {
"max_depth": [2, 3, 5, 10, 20],
"min_samples_split": [5, 10, 20, 50, 100],
"criterion": ["gini", "entropy"]
}
scoring_metrics = ["accuracy", "precision_macro", "recall_macro", "f1_macro"]
#recordar que arbol2 es el árbol cuyas VI son todas las variables.
# cv = crossvalidation
grid_search = GridSearchCV(estimator=arbol2,
param_grid=params,
cv=4, scoring = scoring_metrics, refit="accuracy")
grid_search.fit(X_train, y_train)
# cv (k-fold) 5 está bien, lo ideal es mínimo 10. Cuantos más folds, más sensible.
# Out:
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Sebitas\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_repr_html\base.py:151, in ReprHTMLMixin._repr_mimebundle_(self, **kwargs)
#     149 output = {"text/plain": repr(self)}
#     150 if get_config()["display"] == "diagram":
# --> 151     output["text/html"] = self._html_repr()
#     152 return output
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_repr_html\estimator.py:480, in estimator_html_repr(estimator)
#     469 html_template = (
#     470     f"<style>{style_with_id}</style>"
#     471     f"<body>"
#    (...)
#     476     '<div class="sk-container" hidden>'
#     477 )
#     479 out.write(html_template)
# --> 480 _write_estimator_html(
#     481     out,
#     482     estimator,
#     483     estimator.__class__.__name__,
#     484     estimator_str,
#     485     first_call=True,
#     486     is_fitted_css_class=is_fitted_css_class,
#     487     is_fitted_icon=is_fitted_icon,
#     488 )
#     489 with open(str(Path(__file__).parent / "estimator.js"), "r") as f:
#     490     script = f.read()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_repr_html\estimator.py:329, in _write_estimator_html(out, estimator, estimator_label, estimator_label_details, is_fitted_css_class, is_fitted_icon, first_call, param_prefix)
#     325 if estimator_label:
#     326     if hasattr(estimator, "get_params") and hasattr(
#     327         estimator, "_get_params_html"
#     328     ):
# --> 329         params = estimator._get_params_html(False, doc_link)._repr_html_inner()
#     330     else:
#     331         params = ""
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:328, in BaseEstimator._get_params_html(self, deep, doc_link)
#     324 ordered_out = {name: out[name] for name in init_default_params if name in out}
#     325 ordered_out.update({name: out[name] for name in remaining_params})
#     327 non_default_ls = tuple(
# --> 328     [name for name, value in ordered_out.items() if is_non_default(name, value)]
#     329 )
#     331 return ParamsDict(
#     332     params=ordered_out,
#     333     non_default=non_default_ls,
#     334     estimator_class=self.__class__,
#     335     doc_link=doc_link,
#     336 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:311, in BaseEstimator._get_params_html.<locals>.is_non_default(param_name, param_value)
#     307 if is_pandas_na(param_value) and not is_pandas_na(
#     308     init_default_params[param_name]
#     309 ):
#     310     return True
# --> 311 if not np.array_equal(
#     312     param_value, init_default_params[param_name]
#     313 ) and not (
#     314     is_scalar_nan(init_default_params[param_name])
#     315     and is_scalar_nan(param_value)
#     316 ):
#     317     return True
#     319 return False
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\numeric.py:2506, in array_equal(a1, a2, equal_nan)
#    2504     return False
#    2505 if not equal_nan:
# -> 2506     return builtins.bool((a1 == a2).all())
#    2507 cannot_have_nan = (_dtype_cannot_hold_nan(a1.dtype)
#    2508                    and _dtype_cannot_hold_nan(a2.dtype))
#    2509 if cannot_have_nan:
#
# AttributeError: 'bool' object has no attribute 'all'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_repr_html\base.py:145, in ReprHTMLMixin._repr_html_inner(self)
#     140 def _repr_html_inner(self):
#     141     """This function is returned by the @property `_repr_html_` to make
#     142     `hasattr(estimator, "_repr_html_") return `True` or `False` depending
#     143     on `get_config()["display"]`.
#     144     """
# --> 145     return self._html_repr()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_repr_html\estimator.py:480, in estimator_html_repr(estimator)
#     469 html_template = (
#     470     f"<style>{style_with_id}</style>"
#     471     f"<body>"
#    (...)
#     476     '<div class="sk-container" hidden>'
#     477 )
#     479 out.write(html_template)
# --> 480 _write_estimator_html(
#     481     out,
#     482     estimator,
#     483     estimator.__class__.__name__,
#     484     estimator_str,
#     485     first_call=True,
#     486     is_fitted_css_class=is_fitted_css_class,
#     487     is_fitted_icon=is_fitted_icon,
#     488 )
#     489 with open(str(Path(__file__).parent / "estimator.js"), "r") as f:
#     490     script = f.read()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_repr_html\estimator.py:329, in _write_estimator_html(out, estimator, estimator_label, estimator_label_details, is_fitted_css_class, is_fitted_icon, first_call, param_prefix)
#     325 if estimator_label:
#     326     if hasattr(estimator, "get_params") and hasattr(
#     327         estimator, "_get_params_html"
#     328     ):
# --> 329         params = estimator._get_params_html(False, doc_link)._repr_html_inner()
#     330     else:
#     331         params = ""
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:328, in BaseEstimator._get_params_html(self, deep, doc_link)
#     324 ordered_out = {name: out[name] for name in init_default_params if name in out}
#     325 ordered_out.update({name: out[name] for name in remaining_params})
#     327 non_default_ls = tuple(
# --> 328     [name for name, value in ordered_out.items() if is_non_default(name, value)]
#     329 )
#     331 return ParamsDict(
#     332     params=ordered_out,
#     333     non_default=non_default_ls,
#     334     estimator_class=self.__class__,
#     335     doc_link=doc_link,
#     336 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:311, in BaseEstimator._get_params_html.<locals>.is_non_default(param_name, param_value)
#     307 if is_pandas_na(param_value) and not is_pandas_na(
#     308     init_default_params[param_name]
#     309 ):
#     310     return True
# --> 311 if not np.array_equal(
#     312     param_value, init_default_params[param_name]
#     313 ) and not (
#     314     is_scalar_nan(init_default_params[param_name])
#     315     and is_scalar_nan(param_value)
#     316 ):
#     317     return True
#     319 return False
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\numeric.py:2506, in array_equal(a1, a2, equal_nan)
#    2504     return False
#    2505 if not equal_nan:
# -> 2506     return builtins.bool((a1 == a2).all())
#    2507 cannot_have_nan = (_dtype_cannot_hold_nan(a1.dtype)
#    2508                    and _dtype_cannot_hold_nan(a2.dtype))
#    2509 if cannot_have_nan:
#
# AttributeError: 'bool' object has no attribute 'all'
# GridSearchCV(cv=4,
#              estimator=DecisionTreeClassifier(max_depth=4,
#                                               min_samples_split=30),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_split': [5, 10, 20, 50, 100]},
#              refit='accuracy',
#              scoring=['accuracy', 'precision_macro', 'recall_macro',
#                       'f1_macro'])

# %%
# Obtener resultados del grid search
results = pd.DataFrame(grid_search.cv_results_)
# Mostrar resultados
print("Resultados de Grid Search:")
print(results[["params","mean_test_accuracy",
"mean_test_precision_macro",
"mean_test_recall_macro", "mean_test_f1_macro"]])
# Obtener el mejor modelo
best_model = grid_search.best_estimator_
print(grid_search.best_estimator_)
#Después de sacar ese best estimator no te quedas con él, tienes que explorar la robustez!!
#hay que representar simepre los hiperparámetros de la profundidad que escogimos con la mediad de bondad de ajuste de interés;
#; a veces, da igual :) Esto es sobre train
# Out:
# Resultados de Grid Search:
#                                                params  mean_test_accuracy  \
# 0   {'criterion': 'gini', 'max_depth': 2, 'min_sam...            0.858333
# 1   {'criterion': 'gini', 'max_depth': 2, 'min_sam...            0.858333
# 2   {'criterion': 'gini', 'max_depth': 2, 'min_sam...            0.858333
# 3   {'criterion': 'gini', 'max_depth': 2, 'min_sam...            0.875000
# 4   {'criterion': 'gini', 'max_depth': 2, 'min_sam...            0.766667
# 5   {'criterion': 'gini', 'max_depth': 3, 'min_sam...            0.866667
# 6   {'criterion': 'gini', 'max_depth': 3, 'min_sam...            0.875000
# 7   {'criterion': 'gini', 'max_depth': 3, 'min_sam...            0.858333
# 8   {'criterion': 'gini', 'max_depth': 3, 'min_sam...            0.875000
# 9   {'criterion': 'gini', 'max_depth': 3, 'min_sam...            0.766667
# 10  {'criterion': 'gini', 'max_depth': 5, 'min_sam...            0.866667
# 11  {'criterion': 'gini', 'max_depth': 5, 'min_sam...            0.875000
# 12  {'criterion': 'gini', 'max_depth': 5, 'min_sam...            0.858333
# 13  {'criterion': 'gini', 'max_depth': 5, 'min_sam...            0.875000
# 14  {'criterion': 'gini', 'max_depth': 5, 'min_sam...            0.766667
# 15  {'criterion': 'gini', 'max_depth': 10, 'min_sa...            0.841667
# 16  {'criterion': 'gini', 'max_depth': 10, 'min_sa...            0.875000
# 17  {'criterion': 'gini', 'max_depth': 10, 'min_sa...            0.858333
# 18  {'criterion': 'gini', 'max_depth': 10, 'min_sa...            0.875000
# 19  {'criterion': 'gini', 'max_depth': 10, 'min_sa...            0.766667
# 20  {'criterion': 'gini', 'max_depth': 20, 'min_sa...            0.841667
# 21  {'criterion': 'gini', 'max_depth': 20, 'min_sa...            0.875000
# 22  {'criterion': 'gini', 'max_depth': 20, 'min_sa...            0.858333
# 23  {'criterion': 'gini', 'max_depth': 20, 'min_sa...            0.875000
# 24  {'criterion': 'gini', 'max_depth': 20, 'min_sa...            0.766667
# 25  {'criterion': 'entropy', 'max_depth': 2, 'min_...            0.850000
# 26  {'criterion': 'entropy', 'max_depth': 2, 'min_...            0.850000
# 27  {'criterion': 'entropy', 'max_depth': 2, 'min_...            0.850000
# 28  {'criterion': 'entropy', 'max_depth': 2, 'min_...            0.883333
# 29  {'criterion': 'entropy', 'max_depth': 2, 'min_...            0.766667
# 30  {'criterion': 'entropy', 'max_depth': 3, 'min_...            0.875000
# 31  {'criterion': 'entropy', 'max_depth': 3, 'min_...            0.891667
# 32  {'criterion': 'entropy', 'max_depth': 3, 'min_...            0.858333
# 33  {'criterion': 'entropy', 'max_depth': 3, 'min_...            0.883333
# 34  {'criterion': 'entropy', 'max_depth': 3, 'min_...            0.766667
# 35  {'criterion': 'entropy', 'max_depth': 5, 'min_...            0.883333
# 36  {'criterion': 'entropy', 'max_depth': 5, 'min_...            0.908333
# 37  {'criterion': 'entropy', 'max_depth': 5, 'min_...            0.850000
# 38  {'criterion': 'entropy', 'max_depth': 5, 'min_...            0.883333
# 39  {'criterion': 'entropy', 'max_depth': 5, 'min_...            0.766667
# 40  {'criterion': 'entropy', 'max_depth': 10, 'min...            0.841667
# 41  {'criterion': 'entropy', 'max_depth': 10, 'min...            0.883333
# 42  {'criterion': 'entropy', 'max_depth': 10, 'min...            0.858333
# 43  {'criterion': 'entropy', 'max_depth': 10, 'min...            0.883333
# 44  {'criterion': 'entropy', 'max_depth': 10, 'min...            0.766667
# 45  {'criterion': 'entropy', 'max_depth': 20, 'min...            0.850000
# 46  {'criterion': 'entropy', 'max_depth': 20, 'min...            0.900000
# 47  {'criterion': 'entropy', 'max_depth': 20, 'min...            0.858333
# 48  {'criterion': 'entropy', 'max_depth': 20, 'min...            0.883333
# 49  {'criterion': 'entropy', 'max_depth': 20, 'min...            0.766667
#
#     mean_test_precision_macro  mean_test_recall_macro  mean_test_f1_macro
# 0                    0.807170                0.833075            0.807579
# 1                    0.807170                0.833075            0.807579
# 2                    0.807170                0.833075            0.807579
# 3                    0.833712                0.893634            0.844574
# 4                    0.383333                0.500000            0.433962
# 5                    0.814773                0.838509            0.821284
# 6                    0.833011                0.831522            0.824756
# 7                    0.807170                0.833075            0.807579
# 8                    0.833712                0.893634            0.844574
# 9                    0.383333                0.500000            0.433962
# 10                   0.820005                0.813665            0.813861
# 11                   0.839261                0.806677            0.818711
# 12                   0.807170                0.833075            0.807579
# 13                   0.833712                0.893634            0.844574
# 14                   0.383333                0.500000            0.433962
# 15                   0.791886                0.760093            0.770402
# 16                   0.839261                0.806677            0.818711
# 17                   0.807170                0.833075            0.807579
# 18                   0.833712                0.893634            0.844574
# 19                   0.383333                0.500000            0.433962
# 20                   0.785302                0.772516            0.775901
# 21                   0.839261                0.806677            0.818711
# 22                   0.807170                0.833075            0.807579
# 23                   0.833712                0.893634            0.844574
# 24                   0.383333                0.500000            0.433962
# 25                   0.798086                0.802795            0.791774
# 26                   0.798086                0.802795            0.791774
# 27                   0.798086                0.802795            0.791774
# 28                   0.841670                0.911491            0.858107
# 29                   0.383333                0.500000            0.433962
# 30                   0.826431                0.856366            0.834886
# 31                   0.853420                0.867236            0.853617
# 32                   0.823663                0.808230            0.802114
# 33                   0.841670                0.911491            0.858107
# 34                   0.383333                0.500000            0.433962
# 35                   0.854881                0.849379            0.843220
# 36                   0.886837                0.878106            0.874393
# 37                   0.798086                0.802795            0.791774
# 38                   0.841670                0.911491            0.858107
# 39                   0.383333                0.500000            0.433962
# 40                   0.809701                0.772516            0.771770
# 41                   0.873527                0.824534            0.826668
# 42                   0.823663                0.808230            0.802114
# 43                   0.841670                0.911491            0.858107
# 44                   0.383333                0.500000            0.433962
# 45                   0.813797                0.790373            0.790026
# 46                   0.882045                0.860248            0.860626
# 47                   0.823663                0.808230            0.802114
# 48                   0.841670                0.911491            0.858107
# 49                   0.383333                0.500000            0.433962
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)

# %%
# Para seleccionar una parametrización específica y la mejor de acuerdo con el criterio
# de GridSearch, acceder a esta y conocer su combinación.
results.iloc[8].params
# (En este caso, son ejemplos de selección aleatorios para ilustrar el script de selección y representación),.
# se selecciona el modelo candidato, y se procede a analizar su robustez a lo largo de cross validation.
res_1 = results[["split0_test_accuracy", "split1_test_accuracy","split2_test_accuracy", "split3_test_accuracy"]].iloc[3]
res_2 = results[["split0_test_accuracy", "split1_test_accuracy","split2_test_accuracy", "split3_test_accuracy"]].iloc[46]
res_3 = results[["split0_test_accuracy", "split1_test_accuracy","split2_test_accuracy", "split3_test_accuracy"]].iloc[35]

# %%
# Crear un boxplot para los cuatro valores de accuracy
plt.boxplot([res_1.values,res_2.values,res_3.values], labels = ["res_1","res_2","res_3"])
plt.title("Boxplots de Accuracy para los 4 Splits")
plt.xlabel("Splits de Cross Validation")
plt.ylabel("Accuracy")
plt.show()
# Nótese en la solución que boxplots con gran amplitud no son deseables,
# ya que se caracterizan por poca robustez de la solución
# Out:
# C:\Users\Sebitas\AppData\Local\Temp\ipykernel_15356\1368377278.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([res_1.values,res_2.values,res_3.values], labels = ["res_1","res_2","res_3"])

# %%
# Obtener el mejor modelo (best estimador, o el seleccionado dado los pasos anteriores).
best_model = grid_search.best_estimator_
# Ajustar el mejor modelo con todo el conjunto de entrenamiento
best_model.fit(X_train, y_train)
# Predicciones en conjunto de entrenamiento y prueba
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# %%
#medidas de bondad de ajuste en train
conf_matrix = confusion_matrix(y_train, y_train_pred)
print("Matriz de Confusión:")
print(conf_matrix)
print("\nMedidas de Desempeño:")
print(classification_report(y_train, y_train_pred))
# Out:
# Matriz de Confusión:
# [[87  5]
#  [ 3 25]]
#
# Medidas de Desempeño:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        92
#            1       0.83      0.89      0.86        28
#
#     accuracy                           0.93       120
#    macro avg       0.90      0.92      0.91       120
# weighted avg       0.94      0.93      0.93       120

# %%
y_train_auc = pd.get_dummies(y_train,drop_first=True)
# Calcular el área bajo la curva ROC (AUC)
y_prob_train = best_model.predict_proba(X_train)[:, 1]
fpr, tpr, thresholds = roc_curve(y_train_auc, y_prob_train)
roc_auc = auc(fpr, tpr)
print(f"\nÁrea bajo la curva ROC (AUC): {roc_auc:.2f}")
# Graficar la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color="darkorange", lw=2, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
plt.xlabel("Tasa de Falsos Positivos (FPR)")
plt.ylabel("Tasa de Verdaderos Positivos (TPR)")
plt.title("Curva ROC")
plt.legend(loc="lower right")
plt.show()
# Out:
# Área bajo la curva ROC (AUC): 0.98

# %%
# medidas de bondad de ajuste en test
conf_matrix = confusion_matrix(y_test, y_test_pred)
print("Matriz de Confusión:")
print(conf_matrix)
print("\nMedidas de Desempeño:")
print(classification_report(y_test, y_test_pred))
# Out:
# Matriz de Confusión:
# [[19  5]
#  [ 3  3]]
#
# Medidas de Desempeño:
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.83        24
#            1       0.38      0.50      0.43         6
#
#     accuracy                           0.73        30
#    macro avg       0.62      0.65      0.63        30
# weighted avg       0.77      0.73      0.75        30

# %%
y_test_auc = pd.get_dummies(y_test,drop_first=True)
# Calcular el área bajo la curva ROC (AUC)
y_prob_test = best_model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test_auc, y_prob_test)
roc_auc_test = auc(fpr, tpr)
print(f"\nÁrea bajo la curva ROC (AUC): {roc_auc:.2f}")
# Graficar la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color="darkorange", lw=2, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
plt.xlabel("Tasa de Falsos Positivos (FPR)")
plt.ylabel("Tasa de Verdaderos Positivos (TPR)")
plt.title("Curva ROC")
plt.legend(loc="lower right")
plt.show()
# Out:
# Área bajo la curva ROC (AUC): 0.98

# %%
plt.figure(figsize=(20, 15))
plot_tree(best_model, feature_names=X.columns.tolist(), filled=True,
proportion = True)
plt.show()

# %%
## Crear nuevas variables
## Petal width con los NAs imputados por la media
## Petal width imputados por la media solo de las puntuaciones que indica el árbol
## Calcular errores de los primeros dos con respecto al original.
