# %% [markdown]
# ## Redes clasificación. Ejemplo Chicago crimes

# %%
#importar las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
import seaborn as sns
import plotly.graph_objects as go
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer, Binarizer, RobustScaler, label_binarize
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, PowerTransformer
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.tree import DecisionTreeClassifier, export_text, DecisionTreeRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc
from sklearn.metrics import make_scorer, mean_absolute_error, mean_squared_error, r2_score

# %%
seed=12345 #fijamos la semilla de aleatorización para que sea la misma en todo el proceso
#Reemplaza con la ruta correcta y nombre de tu archivo
file_path = 'C:/Users/user/OneDrive - Universidad Complutense de Madrid (UCM)/Documentos/Titulo Propio/Machine Learning/Redes Neuronales/Python/Datasets/Chicago_Crimes_2012_to_2017.csv' 
#convertir a data frame el archivo
data = pd.read_csv(file_path)
variables = data.columns.values 

data = data.drop(columns=[variables[0]])  ## quitamos la primera variable que no dice nada

print(f'Número de filas: {data.shape[0]}, Número de columnas:{data.shape[1]}') 
data.head()
data.info()
# Out:
# Número de filas: 12428, Número de columnas:7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12428 entries, 0 to 12427
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  12428 non-null  object
#  1   Location Description  12390 non-null  object
#  2   Arrest                12428 non-null  bool
#  3   Beat                  12428 non-null  int64
#  4   District              12428 non-null  int64
#  5   Latitude              11825 non-null  float64
#  6   Longitude             11825 non-null  float64
# dtypes: bool(1), float64(2), int64(2), object(2)
# memory usage: 594.8+ KB

# %%
num_cols=['Beat','District','Latitude','Longitude']

# %%
data.head()
# Out:
#                      Date Location Description  Arrest  Beat  District  \
# 0  05/03/2016 11:40:00 PM            APARTMENT    True  1022        10
# 1  05/03/2016 09:40:00 PM            RESIDENCE   False   313         3
# 2  05/03/2016 11:31:00 PM               STREET   False  1524        15
# 3  05/03/2016 10:10:00 PM             SIDEWALK   False  1532        15
# 4  05/03/2016 10:00:00 PM            RESIDENCE   False  1523        15
#
#     Latitude  Longitude
# 0  41.864073 -87.706819
# 1  41.782922 -87.604363
# 2  41.894908 -87.758372
# 3  41.885687 -87.749516
# 4  41.886297 -87.761751

# %%
#### FE y depuración de datos ##
## Primero vemos cuantos missing tenemos en cada variable ##
data.isnull().sum()

data = data[~data["Latitude"].isnull()] ## eliminamos los datos mising 
data.isnull().sum()

data = data[~data["Location Description"].isnull()] ## eliminamos los datos mising 
data.isnull().sum()  ## sin missing ya (podriamos haberlos imputado pero en este caso no tiene sentido)

## si quiero quitarme todos de un solo paso
#data = data.dropna(axis=1)
# Out:
# Date                    0
# Location Description    0
# Arrest                  0
# Beat                    0
# District                0
# Latitude                0
# Longitude               0
# dtype: int64

# %%
## separamos la variable target de las variables eplicativas si quisieramos hacer un modelo predictivo
variables = data.columns.values 
X = data[[variables[2], variables[3], variables[4], variables[5], variables[6],]]
y = data[variables[1]]

X.info()
X.describe()
y.value_counts()
y.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11803 entries, 0 to 12427
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Arrest     11803 non-null  bool
#  1   Beat       11803 non-null  int64
#  2   District   11803 non-null  int64
#  3   Latitude   11803 non-null  float64
#  4   Longitude  11803 non-null  float64
# dtypes: bool(1), float64(2), int64(2)
# memory usage: 472.6 KB
# 0    APARTMENT
# 1    RESIDENCE
# 2       STREET
# 3     SIDEWALK
# 4    RESIDENCE
# Name: Location Description, dtype: object

# %%
# Se generan dummies para las variables no continuas
## se puede estudiar reducir el numero de categorias para la variable Localizacion
data= data.rename({'Location Description': 'Location'}, axis=1)
data['Location'] = data.Location.apply(lambda x: x if x in ['STREET','RESIDENCE','APARTMENT','SIDEWALK', 'PARKING LOT/GARAGE(NON.RESID.)'] else 'Otros')

table_location=pd.DataFrame(data["Location"].value_counts())
print(table_location)


# Creamos dummies solo para la red, en el resto sea realizará en el pipeline
data_dummies = pd.get_dummies(data,columns=['Location'], drop_first= True)
data_dummies.head()

## separamos la variable target de las variables eplicativas 
variables = data_dummies.columns.values 
X_all = data_dummies.drop('Arrest', axis=1) # en realidad la creación de dummies la podría llevar con ColumnTransformer al flujo de ML
y = data_dummies["Arrest"]
# Out:
#                                 count
# Location
# Otros                            4333
# STREET                           2653
# RESIDENCE                        1886
# APARTMENT                        1478
# SIDEWALK                         1124
# PARKING LOT/GARAGE(NON.RESID.)    329

# %%
#en X_all tenemos las variables con dummies
X_all.head()
# Out:
#                      Date  Beat  District   Latitude  Longitude  \
# 0  05/03/2016 11:40:00 PM  1022        10  41.864073 -87.706819
# 1  05/03/2016 09:40:00 PM   313         3  41.782922 -87.604363
# 2  05/03/2016 11:31:00 PM  1524        15  41.894908 -87.758372
# 3  05/03/2016 10:10:00 PM  1532        15  41.885687 -87.749516
# 4  05/03/2016 10:00:00 PM  1523        15  41.886297 -87.761751
#
#    Location_Otros  Location_PARKING LOT/GARAGE(NON.RESID.)  \
# 0           False                                    False
# 1           False                                    False
# 2           False                                    False
# 3           False                                    False
# 4           False                                    False
#
#    Location_RESIDENCE  Location_SIDEWALK  Location_STREET
# 0               False              False            False
# 1                True              False            False
# ...

# %% [markdown]
# ## ESTO NO ES CORRECTO PARA ML
# Porque hay que buscar la transformación en train. Pero es una idea de cómo mantener el objeto `pd.DataFrame` después de las transformaciones
#
# ```python
# #Si quisiéramos escalar variables numéricas
# #Si se quisieran estandarizar, scaler=StandardScaler()
# scaler = MinMaxScaler() #selecciona el transformador
# X_nume = X_all[num_cols] #selecciona las variables numéricas que se quieren transformar y las guarda en un nuevo dataframe
# X_scale = pd.DataFrame(scaler.fit_transform(X_nume)) #guarda el resultado de la transformación de las variables de X en X_scale
# X_scale.columns = X_nume.columns #para simplificar los nombres, asigna a las columnas de X_scale los nombres de las variables de X_num
# data[num_cols] = X_scale
# ```

# %%
#En X_all tenemos las categoricas convertidas a dummies
X_all.head()
# Out:
#                      Date  Beat  District   Latitude  Longitude  \
# 0  05/03/2016 11:40:00 PM  1022        10  41.864073 -87.706819
# 1  05/03/2016 09:40:00 PM   313         3  41.782922 -87.604363
# 2  05/03/2016 11:31:00 PM  1524        15  41.894908 -87.758372
# 3  05/03/2016 10:10:00 PM  1532        15  41.885687 -87.749516
# 4  05/03/2016 10:00:00 PM  1523        15  41.886297 -87.761751
#
#    Location_Otros  Location_PARKING LOT/GARAGE(NON.RESID.)  \
# 0           False                                    False
# 1           False                                    False
# 2           False                                    False
# 3           False                                    False
# 4           False                                    False
#
#    Location_RESIDENCE  Location_SIDEWALK  Location_STREET
# 0               False              False            False
# 1                True              False            False
# ...

# %% [markdown]
# ## OJO
# Con la propuesta de variables explicativas, no es necesario estandarizar: son dummies que ya cumplen el criterio.

# %%
import warnings
from sklearn.exceptions import DataConversionWarning, UndefinedMetricWarning

# Ignorar warnings concretos
warnings.filterwarnings("ignore", category=DataConversionWarning)
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

# %%
X = X_all[['Location_RESIDENCE','Location_SIDEWALK']] 
y = data['Arrest']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)


red = MLPClassifier(random_state=seed)
#definimos los parámetros que queremos tunear
params = {
    'max_iter': [600],
    'hidden_layer_sizes': [5,7,9],
    'activation': ['tanh','relu'],
    'alpha': [0.001,0.0001]
}
scoring_metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']
# cv = crossvalidation con n folds con todas las combinaciones de parámetros
grid_search = GridSearchCV(estimator=red, 
                           param_grid=params, 
                           cv=4, scoring = scoring_metrics, refit='accuracy')

#ajusta en entrenamiento con todas las combinaciones
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=MLPClassifier(random_state=12345),
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.001, 0.0001],
#                          'hidden_layer_sizes': [5, 7, 9], 'max_iter': [600]},
#              refit='accuracy',
#              scoring=['accuracy', 'precision_macro', 'recall_macro',
#                       'f1_macro'])

# %%
# Obtener resultados del grid search
results = pd.DataFrame(grid_search.cv_results_)
# Mostrar resultados
print("Resultados de Grid Search:")
print(results[['params', 'mean_test_accuracy', 'mean_test_precision_macro', 'mean_test_recall_macro', 'mean_test_f1_macro']])
#print(results) #para ver todos los atributos obtenidos y entender cómo usarlos

# Obtener el mejor modelo (en cuanto a optimización del criterio)
best_model = grid_search.best_estimator_
print(grid_search.best_estimator_)
# Out:
# Resultados de Grid Search:
#                                                params  mean_test_accuracy  \
# 0   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.758843
# 1   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.758843
# 2   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.758843
# 3   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.758843
# 4   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.758843
# 5   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.758843
# 6   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.758843
# 7   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.758843
# 8   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.758843
# 9   {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.758843
# 10  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.758843
# ...

# %% [markdown]
# ## Cómo analizar tantos resultados, una idea
# Como `refit=accuracy`, puedo asumir que mi métrica de interés es el accuracy. Aunque puedo analizar todas las arquitecturas, una forma de filtrar y empezar a decidir es ordenar el conjunto de resultados de mayor a menor promedio en test de accuracy

# %%
import pandas as pd

# Supongamos que tienes un DataFrame df con la columna mean_test_accuracy
results = results.sort_values(by='mean_test_accuracy', ascending=False)  # de mayor a menor

# %%
# se seleccionan los modelos candidatos, y analiza su robustez a lo largo de cross validation.
ac_1 = results[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[0]
ac_2 = results[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[1]
ac_3 = results[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[2]

# %%
# Crear un boxplot para los cuatro valores de accuracy
plt.boxplot([ac_1.values,ac_2.values,ac_3.values], tick_labels = ['Red0','Red1','Red2'])
plt.title('Boxplots de Accuracy para los 4 Splits')
plt.xlabel('Splits de Cross Validation')
plt.ylabel('Accuracy')
plt.show()

# %%
print(f'Arquitectura red 0: {results.iloc[0].params}')
print(f'Arquitectura red 1: {results.iloc[1].params}')
print(f'Arquitectura red 2: {results.iloc[2].params}')
# Out:
# Arquitectura red 0: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 5, 'max_iter': 600}
# Arquitectura red 1: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 7, 'max_iter': 600}
# Arquitectura red 2: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 9, 'max_iter': 600}

# %% [markdown]
# A igualdad de condiciones, me quedo con la red ocn 5 nodos en la capa oculta, por ser la más sencilla. Como 5 está en el extremo de la parrilla `hidden_layer_sizes': [5,7,9]` debo seguir buscando por si mejoro algo con menos nodos

# %%
X = X_all[['Location_RESIDENCE','Location_SIDEWALK']] 
y = data['Arrest']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)


red2 = MLPClassifier(random_state=seed)
#definimos los parámetros que queremos tunear
params2 = {
    'max_iter': [600],
    'hidden_layer_sizes': [3,4,5],
    'activation': ['tanh','relu'],
    'alpha': [0.001,0.0001]
}
scoring_metrics = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']
# cv = crossvalidation con n folds con todas las combinaciones de parámetros
grid_search2 = GridSearchCV(estimator=red2, 
                           param_grid=params2, 
                           cv=4, scoring = scoring_metrics, refit='accuracy')

#ajusta en entrenamiento con todas las combinaciones
grid_search2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=MLPClassifier(random_state=12345),
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.001, 0.0001],
#                          'hidden_layer_sizes': [3, 4, 5], 'max_iter': [600]},
#              refit='accuracy',
#              scoring=['accuracy', 'precision_macro', 'recall_macro',
#                       'f1_macro'])

# %%
# Obtener resultados del grid search
results2 = pd.DataFrame(grid_search2.cv_results_)
# Mostrar resultados
print("Resultados de Grid Search:")
print(results2[['params', 'mean_test_accuracy', 'mean_test_precision_macro', 'mean_test_recall_macro', 'mean_test_f1_macro']])
#print(results) #para ver todos los atributos obtenidos y entender cómo usarlos

# Obtener el mejor modelo (en cuanto a optimización del criterio)
best_model2 = grid_search2.best_estimator_
print(grid_search2.best_estimator_)
# Out:
# Resultados de Grid Search:
#                                                params  mean_test_accuracy  \
# 0   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.758843
# 1   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.758843
# 2   {'activation': 'tanh', 'alpha': 0.001, 'hidden...            0.758843
# 3   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.758843
# 4   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.758843
# 5   {'activation': 'tanh', 'alpha': 0.0001, 'hidde...            0.758843
# 6   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.758843
# 7   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.758843
# 8   {'activation': 'relu', 'alpha': 0.001, 'hidden...            0.758843
# 9   {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.758843
# 10  {'activation': 'relu', 'alpha': 0.0001, 'hidde...            0.758843
# ...

# %%
import pandas as pd

# Supongamos que tienes un DataFrame df con la columna mean_test_accuracy
results2 = results2.sort_values(by='mean_test_accuracy', ascending=False)  # de mayor a menor

# se seleccionan los modelos candidatos, y analiza su robustez a lo largo de cross validation.
ac_12 = results2[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[0]
ac_22 = results2[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[1]
ac_32 = results2[['split0_test_accuracy', 'split1_test_accuracy','split2_test_accuracy', 'split3_test_accuracy']].iloc[2]

# %%
# Crear un boxplot para los cuatro valores de accuracy
plt.boxplot([ac_12.values,ac_22.values,ac_32.values], tick_labels = ['Red0_2','Red1_2','Red2_2'])
plt.title('Boxplots de Accuracy para los 4 Splits')
plt.xlabel('Splits de Cross Validation')
plt.ylabel('Accuracy')
plt.show()

# %%
print(f'Arquitectura red 0_2: {results2.iloc[0].params}')
print(f'Arquitectura red 1_2: {results2.iloc[1].params}')
print(f'Arquitectura red 2_2: {results2.iloc[2].params}')
# Out:
# Arquitectura red 0_2: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 3, 'max_iter': 600}
# Arquitectura red 1_2: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 4, 'max_iter': 600}
# Arquitectura red 2_2: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': 5, 'max_iter': 600}

# %% [markdown]
# # Paso final
# Una vez que hemos escogido nuestro modelo candidato ganador, después de haber hecho todas las pruebas de CV que garantizan estabilidad y haber expuesto los argumentos que sustentan por qué es mi modelo candidato, tengo que volver a hacer la partición tr/ts, entrenar el modelo replicando exactamente el flujo de trabajo (incluyendo transformaciones y selección de variables), y volver a entrenarlo. Los parámetros obtenidos en entrenamiento serán los que se lleven a la producción. La calidad evaluada para esos parámetros en la parte de test, será la calidad final de mi modelo.
#
# **IMPORTANTE** replicar el proceso de preparación hasta llegar a la arquitectura de la red

# %% [markdown]
# ## Decisión
# Ante igualdad de condiciones, nos quedamos con el modelo más sencillo, con tres neuronas en la capa oculta. Podríamos seguir buscando, o comparar más de 3 modelos (de hecho, se debería hacer).
# A modo ilustrativo, nos quedamos con el modelo red 0_2 como candidato.
# Como paso final, habrá que tomar el proceso de preparación de los datos y la parametrización concreta, volver a entrenarlo para definir los parámetros, y evaluarlo en test para conseguir una evaluación adecuada

# %%
#analizar y reentrenar redes candidatas AUC
from sklearn.preprocessing import LabelBinarizer
X = X_all[['Location_RESIDENCE','Location_SIDEWALK']] #en X las variables ya están con dummies
y = data['Arrest']
lb = LabelBinarizer()
y_bin = lb.fit_transform(y).ravel()   # produce 0/1#para calcular el AUC, y debe ser numérica
X_train, X_test, y_train, y_test = train_test_split(X, y_bin, test_size=0.2, random_state=seed)


candidata = MLPClassifier(**results2.iloc[0].params,random_state=seed)
candidata.fit(X_train, y_train)


# Calculamos las predicciones en test, en términos de probabilidad para poder dibujar el AUC
y_pred = candidata.predict_proba(X_test)[:,1]

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print(f"\nÁrea bajo la curva ROC (AUC) para la red 0 en test: {roc_auc:.2f}")

# Graficar la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC candidata')
plt.legend(loc="lower right")
plt.show()

#calculamos las predicciones en test, en términos de probabilidad para poder dibujar el AUC
y_pred = candidata.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
print("Matriz de Confusión:")
print(conf_matrix)
print("\nMedidas de Desempeño:")
print(classification_report(y_test, y_pred))

#También podríamos haber binarizado y_pred proba con el umbral que mejor nos venga
# Out:
# Área bajo la curva ROC (AUC) para la red 0 en test: 0.57
# Matriz de Confusión:
# [[1839    0]
#  [ 522    0]]
#
# Medidas de Desempeño:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      1839
#            1       0.00      0.00      0.00       522
#
#     accuracy                           0.78      2361
#    macro avg       0.39      0.50      0.44      2361
# weighted avg       0.61      0.78      0.68      2361

# %% [markdown]
# # Conclusión final
# La matriz de confusión nos dice que este modelo no está haciendo nada!! No es capaz de detectar ningún valor positivo!!! No puedo darlo por bueno, tengo que volver a empezar, tal vez, modificando las variables explicativas.
# Consigue tener un accuracy relativamente bueno porque las clases están muy desbalanceadas y el modelo pronto entiende que diciendo siempre 0, lo hace relativamente bien en general.
# No obstante, NO SIRVE
